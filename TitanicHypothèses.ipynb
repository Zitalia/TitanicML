# %%
import pandas as pd
import numpy as np
import scipy.stats 
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_clean=pd.read_csv('data/train_clean.csv')
test_clean=pd.read_csv('data/test_clean.csv')

# %% [markdown]
#  # les femmes ayant embarqué sur le titanic avaient-elles plus de chance de survie que les hommes?

# %% [markdown]
# ## Ho: il n'existe pas de corrélation entre le sexe du passager et la survie
# ## H1: il existe une corrélation entre le sexe du passager et la survie

# %%
train_clean.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
train_clean=pd.get_dummies(train_clean)

# %%
train_clean.corr(method='pearson')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.034212 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.064910 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.339898  0.083081  0.018443
# Age             0.034212 -0.064910 -0.339898  1.000000 -0.233296 -0.172482
# SibSp          -0.057527 -0.035322  0.083081 -0.233296  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.172482  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096688  0.159651  0.216225
# Sex_female     -0.042939  0.543351 -0.131900 -0.081163  0.114631  0.245489
# Sex_male        0.042939 -0.543351  0.131900  0.081163 -0.114631 -0.245489
# Embarked_C     -0.001205  0.168240 -0.243292  0.030248 -0.059528 -0.011069
# Embarked_Q     -0.033606  0.003650  0.221009 -0.031415 -0.026354 -0.081228
# Embarked_S      0.022204 -0.149683  0.074053 -0.006729  0.068734  0.060814
#
#                  Fare  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# PassengerId  0.012658   -0.042939  0.042939   -0.001205   -0.033606
# Survived     0.257307    0.543351 -0.543351    0.168240    0.003650
# Pclass      -0.549500   -0.131900  0.131900   -0.243292    0.221009
# Age          0.096688   -0.081163  0.081163    0.030248   -0.031415
# SibSp        0.159651    0.114631 -0.114631   -0.059528   -0.026354
# Parch        0.216225    0.245489 -0.245489   -0.011069   -0.081228
# Fare         1.000000    0.182333 -0.182333    0.269335   -0.117216
# Sex_female   0.182333    1.000000 -1.000000    0.082853    0.074115
# Sex_male    -0.182333   -1.000000  1.000000   -0.082853   -0.074115
# Embarked_C   0.269335    0.082853 -0.082853    1.000000   -0.148258
# Embarked_Q  -0.117216    0.074115 -0.074115   -0.148258    1.000000
# Embarked_S  -0.162184   -0.119224  0.119224   -0.782742   -0.499421
#
#              Embarked_S
# PassengerId    0.022204
# Survived      -0.149683
# Pclass         0.074053
# Age           -0.006729
# SibSp          0.068734
# Parch          0.060814
# Fare          -0.162184
# Sex_female    -0.119224
# Sex_male       0.119224
# Embarked_C    -0.782742
# Embarked_Q    -0.499421
# Embarked_S     1.000000

# %%
train_clean.corr(method='spearman')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.034091  0.034584 -0.061161  0.001235
# Survived       -0.005007  1.000000 -0.339668 -0.037004  0.088879  0.138266
# Pclass         -0.034091 -0.339668  1.000000 -0.317406 -0.043019 -0.022801
# Age             0.034584 -0.037004 -0.317406  1.000000 -0.145316 -0.217488
# SibSp          -0.061161  0.088879 -0.043019 -0.145316  1.000000  0.450014
# Parch           0.001235  0.138266 -0.022801 -0.217488  0.450014  1.000000
# Fare           -0.013975  0.323736 -0.688032  0.126006  0.447113  0.410074
# Sex_female     -0.042939  0.543351 -0.135775 -0.067663  0.195204  0.254512
# Sex_male        0.042939 -0.543351  0.135775  0.067663 -0.195204 -0.254512
# Embarked_C     -0.001205  0.168240 -0.220995  0.019634  0.014188  0.023115
# Embarked_Q     -0.033606  0.003650  0.229763 -0.020950 -0.048537 -0.099250
# Embarked_S      0.022204 -0.149683  0.049011 -0.004016  0.018115  0.042209
#
#                  Fare  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# PassengerId -0.013975   -0.042939  0.042939   -0.001205   -0.033606
# Survived     0.323736    0.543351 -0.543351    0.168240    0.003650
# Pclass      -0.688032   -0.135775  0.135775   -0.220995    0.229763
# Age          0.126006   -0.067663  0.067663    0.019634   -0.020950
# SibSp        0.447113    0.195204 -0.195204    0.014188   -0.048537
# Parch        0.410074    0.254512 -0.254512    0.023115   -0.099250
# Fare         1.000000    0.259593 -0.259593    0.204104   -0.232149
# Sex_female   0.259593    1.000000 -1.000000    0.082853    0.074115
# Sex_male    -0.259593   -1.000000  1.000000   -0.082853   -0.074115
# Embarked_C   0.204104    0.082853 -0.082853    1.000000   -0.148258
# Embarked_Q  -0.232149    0.074115 -0.074115   -0.148258    1.000000
# Embarked_S  -0.032712   -0.119224  0.119224   -0.782742   -0.499421
#
#              Embarked_S
# PassengerId    0.022204
# Survived      -0.149683
# Pclass         0.049011
# Age           -0.004016
# SibSp          0.018115
# Parch          0.042209
# Fare          -0.032712
# Sex_female    -0.119224
# Sex_male       0.119224
# Embarked_C    -0.782742
# Embarked_Q    -0.499421
# Embarked_S     1.000000

# %%
train_clean.corr(method='spearman').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'))
# Out:
# <style  type="text/css" >
#     #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col1 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col2 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col3 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col4 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col6 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col7 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col8 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col9 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col10 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row0_col11 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col0 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col3 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col4 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col5 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col6 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col7 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col8 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col9 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col10 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row1_col11 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col1 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col4 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col5 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col7 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col8 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col9 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col10 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row2_col11 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col0 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col1 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col2 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col4 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col5 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col6 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col7 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col8 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col9 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col10 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row3_col11 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col1 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col2 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col5 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col6 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col7 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col8 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col9 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col10 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_81325c76_7977_11ea_8dec_e82aeab2ad62row4_col11 {
#             background-color:  #cfdaea;
#             color:  #0

# %%
from scipy.stats import chi2_contingency
contingence = pd.crosstab(train_clean['Sex_female'],train_clean['Survived'],  margins=True)
chi2, p, dof, ex = chi2_contingency(contingence)
alpha = 1.0 - 0.95
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# significance=0.050, p=0.000
# Dependent (reject H0)

# %% [markdown]
# Analyse: la p value (0.000) est inférieure à 0.05 donc le fait de connaitre le sexe d'un passager a une influence sur la survie lors du naufrage

# %%
from scipy.stats import stats
contingence2 = pd.crosstab(train_clean['Sex_male'],train_clean['Survived'])
oddsratio, pvalue = stats.fisher_exact(contingence2)
pvalue
# Out:
# 6.46392156458115e-60

# %% [markdown]
# le test de Fisher confirme la dépendance des variables

# %% [markdown]
# # Avoir moins de 18 ans donne-t-il plus de chance de  survie lors du naufrage du Titanic ?

# %% [markdown]
# ## H0 : Il n'éxiste pas de corrélation entre la survie et le fait d'être agé de moins de 18 ans , les variables sont indépendantes.<br>
# ## h1 : Il existe une corrélation entre la survie et le fait d'être agé de moins de 18 ans

# %%
newval = ''
for index , i in train_clean.iterrows():
    if i['Age'] >18:
        newval = 0
    else :
        newval = 1
    train_clean.at[index,'Age'] = newval

# %%
from scipy.stats import chi2_contingency
contingence3 = pd.crosstab(train_clean['Age'],train_clean['Survived'])
chi2, p, dof, ex = chi2_contingency(contingence3)
alpha = 1.0 - 0.95
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# significance=0.050, p=0.002
# Dependent (reject H0)

# %% [markdown]
# La Pvalue est de 0.002, soit en dessous de notre alpha de 0.05, Nous rejetons h0, et nous confirmons que les 2 features sont liées.
# Nous confirmons cela avec un test de fisher

# %%
contingence3 = pd.crosstab(train_clean['Age'],train_clean['Survived'])
oddsratio, pvalue = scipy.stats.fisher_exact(contingence3)
pvalue
# Out:
# 0.0022911292216911162

# %% [markdown]
# La dépendance des 2 variables est confirmée

# %% [markdown]
# # Le prix du billet a-t-il eu une incidence sur la survie des passagers?

# %% [markdown]
# ## Ho : Le prix du billet n'a pas eu d'incidence sur la survie
# ## H1: le prix a eu une incidence

# %%
contingence4 = pd.crosstab(train_clean['Fare'],train_clean['Survived'])
chi2, p, dof, ex = chi2_contingency(contingence4)
alpha = 1.0 - 0.95
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# significance=0.050, p=0.000
# Dependent (reject H0)

# %% [markdown]
# La Pvalue est de 0.000, soit en dessous de notre alpha de 0.05, Nous rejetons h0, et nous confirmons que les 2 features sont liées.

# %%
print(train_clean['Fare'].head())
print(train_clean['Fare'].mean())
print(train_clean['Fare'].median())
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64
# 32.2042079685746
# 14.4542

# %%
newfare = ''
for index , i in train_clean.iterrows():
    
    if i['Fare'] > 32:

        newfare = 0
    else :
        newfare = 1
    train_clean.at[index,'Fare'] = newfare

# %%
contingence4 = pd.crosstab(train_clean['Fare'],train_clean['Survived'], margins=False)
oddsratio, pvalue = scipy.stats.fisher_exact(contingence4)
pvalue
# Out:
# 8.871807500023419e-13

# %% [markdown]
# Le test de fisher confirme l'influence du tarif du billet sur la survie du passager

# %% [markdown]
# ## Conclusion: nous allons pouvoir étudier plus en détail l'influence de ces variables sur la prédictions de la survie des passagers
